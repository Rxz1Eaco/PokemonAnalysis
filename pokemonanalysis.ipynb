# %% [markdown]
# ### Criando o ambiente para análise

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Explicação sobre a nomeclatura:
# - Dataframe: Quadro de dados
# - Dataset: Conjunto de dados

# %% [markdown]
# ### Carregando os dados em xlsx

# %%
df_pokemon = pd.read_excel("pokemon.xlsx")
display(df_pokemon)
# Out:
#      national_number   gen english_name japanese_name primary_type  \
# 0                  1     I    Bulbasaur   Fushigidane        grass
# 1                  2     I      Ivysaur    Fushigisou        grass
# 2                  3     I     Venusaur   Fushigibana        grass
# 3                  4     I   Charmander      Hitokage         fire
# 4                  5     I   Charmeleon       Lizardo         fire
# ..               ...   ...          ...           ...          ...
# 893              894  VIII    Regieleki     Regieleki     electric
# 894              895  VIII    Regidrago     Regidrago       dragon
# 895              896  VIII    Glastrier      Blizapos          ice
# 896              897  VIII    Spectrier       Rayspos        ghost
# 897              898  VIII      Calyrex        Badrex      psychic
#
#     secondary_type       classification percent_male percent_female  height_m  \
# 0           poison         Seed Pokémon        88.14          11.86       0.7
# ...

# %% [markdown]
# ### Método Head
# - Tem como objetivo : Mostrar os primeiros dados do dataframe
# - Exemplo: df_nome.head() ou df_nome.head(5) -> Aqui mostrar os 5° primeiros dados do dataframe

# %%
df_pokemon.head(3)
# Out:
#    national_number gen english_name japanese_name primary_type secondary_type  \
# 0                1   I    Bulbasaur   Fushigidane        grass         poison
# 1                2   I      Ivysaur    Fushigisou        grass         poison
# 2                3   I     Venusaur   Fushigibana        grass         poison
#
#   classification percent_male percent_female  height_m  ...  evochain_1  \
# 0   Seed Pokémon        88.14          11.86       0.7  ...      Level
# 1   Seed Pokémon        88.14          11.86       1.0  ...      Level
# 2   Seed Pokémon        88.14          11.86       2.0  ...      Level
#
#   evochain_2  evochain_3  evochain_4  evochain_5  evochain_6  \
# 0    Ivysaur      Level     Venusaur         NaN         NaN
# 1    Ivysaur      Level     Venusaur         NaN         NaN
# 2    Ivysaur      Level     Venusaur         NaN         NaN
#
#             gigantamax  mega_evolution  mega_evolution_alt  \
# ...

# %% [markdown]
# ### Método Tail
# - Tem como objetivo : Mostrar últimos dados do dataframe
# - Exemplo: df_nome.tail() ou df_nome.tail(5) -> Aqui mostra os últimos 5° dados do dataframe

# %%
df_pokemon.tail(3)
# Out:
#      national_number   gen english_name japanese_name primary_type  \
# 895              896  VIII    Glastrier      Blizapos          ice
# 896              897  VIII    Spectrier       Rayspos        ghost
# 897              898  VIII      Calyrex        Badrex      psychic
#
#     secondary_type       classification percent_male percent_female  height_m  \
# 895            NaN   Wild Horse Pokémon          NaN            NaN       2.2
# 896            NaN  Swift Horse Pokémon          NaN            NaN       2.0
# 897          grass         King Pokémon          NaN            NaN       1.1
#
#      ...  evochain_1 evochain_2  evochain_3  evochain_4  evochain_5  \
# 895  ...         NaN        NaN         NaN         NaN         NaN
# 896  ...         NaN        NaN         NaN         NaN         NaN
# 897  ...         NaN        NaN         NaN         NaN         NaN
#
#      evochain_6  gigantamax  mega_evolution  mega_evolution_alt  \
# ...

# %% [markdown]
# ### Método Sample
# - Tem como objetivo : Mostrar dados misturado
# - Exemplo: df_nome.sample() ou df_nome.sample(5) -> Aqui mostra os 5° dados misturados do dataframe

# %%
df_pokemon.sample(3)
# Out:
#      national_number   gen english_name japanese_name primary_type  \
# 809              810  VIII      Grookey      Sarunori        grass
# 530              531     V       Audino       Tabunne       normal
# 465              466    IV   Electivire      Elekible     electric
#
#     secondary_type       classification percent_male percent_female  height_m  \
# 809            NaN        Chimp Pokémon        88.14          11.86       0.3
# 530            NaN      Hearing Pokémon         50.2           49.8       1.1
# 465            NaN  Thunderbolt Pokémon        75.49          24.51       1.8
#
#      ...  evochain_1  evochain_2               evochain_3  evochain_4  \
# 809  ...      Level     Thwackey                   Level    Rillaboom
# 530  ...         NaN         NaN                      NaN         NaN
# 465  ...      Level   Electabuzz  Trade with  Electirizer  Electivire
#
#      evochain_5  evochain_6  gigantamax  mega_evolution  mega_evolution_alt  \
# ...

# %% [markdown]
# ### Métodos Info e describe
#  - Serve para dar uma visão geral nos dados que ainda não conhecemos

# %% [markdown]
# ### Método Info
# - Tem como objetivo : Mostrar informações estatísticas
# - Exemplo: df_nome.info()

# %%
df_pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 898 entries, 0 to 897
# Data columns (total 55 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   national_number     898 non-null    int64
#  1   gen                 898 non-null    object
#  2   english_name        898 non-null    object
#  3   japanese_name       898 non-null    object
#  4   primary_type        898 non-null    object
#  5   secondary_type      469 non-null    object
#  6   classification      898 non-null    object
#  7   percent_male        776 non-null    object
#  8   percent_female      776 non-null    object
#  9   height_m            898 non-null    float64
#  10  weight_kg           898 non-null    float64
#  11  capture_rate        898 non-null    object
#  12  base_egg_steps      898 non-null    int64
#  13  hp                  898 non-null    int64
#  14  attack              898 non-null    int64
# ...

# %% [markdown]
# ### Método describe
# - Tem como objetivo : Resumo de informações estatísticas importantes
# - Exemplo: df_nome.describe()

# %%
df_pokemon.describe()
# Out:
#        national_number    height_m   weight_kg  base_egg_steps          hp  \
# count       898.000000  898.000000  898.000000      898.000000  898.000000
# mean        449.500000    1.185969   63.970045     7544.587973   69.031180
# std         259.374568    1.234222  119.430298     7101.313608   26.213707
# min           1.000000    0.100000    0.100000     1280.000000    1.000000
# 25%         225.250000    0.500000    8.500000     5120.000000   50.000000
# 50%         449.500000    1.000000   27.000000     5120.000000   65.000000
# 75%         673.750000    1.500000   65.000000     6400.000000   80.000000
# max         898.000000   20.000000  999.900000    30720.000000  255.000000
#
#            attack     defense   sp_attack  sp_defense       speed  ...  \
# count  898.000000  898.000000  898.000000  898.000000  898.000000  ...
# mean    76.544543   71.886414   69.681514   69.876392   65.949889  ...
# std     29.665559   29.536184   29.372609   27.012142   28.456596  ...
# ...

# %% [markdown]
# ## Método Shape
# - Tem como objetivo : Mostrar total de linhas e Colunas em um dataframe
# - Exemplo: df_nome.shape

# %%
linhas, colunas = df_pokemon.shape
print(f"Podemos Observar que essa database tem um total de {linhas} linhas e um total de {colunas} colunas")
# Out:
# Podemos Observar que essa database tem um total de 898 linhas e um total de 55 colunas

# %% [markdown]
# ### Selecionando subconjuntos do Dataframe
# - Selecionando uma coluna específica

# %%
colums_type = df_pokemon["primary_type"]
display(colums_type)
# Out:
# 0         grass
# 1         grass
# 2         grass
# 3          fire
# 4          fire
#          ...
# 893    electric
# 894      dragon
# 895         ice
# 896       ghost
# 897     psychic
# Name: primary_type, Length: 898, dtype: object

# %% [markdown]
# ### Contagem por Tipos de Pokémon

# %%
contagem_tipos = df_pokemon["primary_type"].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(contagem_tipos.index, contagem_tipos, color=['#78C850', '#F08030', '#6890F0', '#F8D030', '#EE99AC'])
plt.title('Histograma de Tipos Primários de Pokémon')
plt.xlabel('Tipo Primário')
plt.ylabel('Quantidade')
plt.xticks(rotation=45, ha='right') 
plt.show()

# %%
contagem_tipos = df_pokemon["secondary_type"].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(contagem_tipos.index, contagem_tipos, color=['#78C850', '#F08030', '#6890F0', '#F8D030', '#EE99AC'])
plt.title('Histograma de Tipos Secondários de Pokémon')
plt.xlabel('Tipo Secondário')
plt.ylabel('Quantidade')
plt.xticks(rotation=45, ha='right') 
plt.show()

# %% [markdown]
# ### Pegando o nome e o primeiro tipo

# %%
name_type_df_pokemon = df_pokemon[["english_name","primary_type"]]
display(name_type_df_pokemon)
# Out:
#     english_name primary_type
# 0      Bulbasaur        grass
# 1        Ivysaur        grass
# 2       Venusaur        grass
# 3     Charmander         fire
# 4     Charmeleon         fire
# ..           ...          ...
# 893    Regieleki     electric
# 894    Regidrago       dragon
# 895    Glastrier          ice
# 896    Spectrier        ghost
# 897      Calyrex      psychic
#
# [898 rows x 2 columns]

# %% [markdown]
# ### Pegando o nome , primeiro tipo e o segundo tipo

# %%
name_type_df_pokemon = df_pokemon[["english_name","primary_type", "secondary_type"]]
display(name_type_df_pokemon)
# Out:
#     english_name primary_type secondary_type
# 0      Bulbasaur        grass         poison
# 1        Ivysaur        grass         poison
# 2       Venusaur        grass         poison
# 3     Charmander         fire            NaN
# 4     Charmeleon         fire            NaN
# ..           ...          ...            ...
# 893    Regieleki     electric            NaN
# 894    Regidrago       dragon            NaN
# 895    Glastrier          ice            NaN
# 896    Spectrier        ghost            NaN
# 897      Calyrex      psychic          grass
#
# [898 rows x 3 columns]

# %% [markdown]
# ## Área de Estudo : Grama 🌱
# ### Pegando todos os pokémons com o primeiro tipo "grama" = 🌱

# %%
grass_df_pokemon = df_pokemon[df_pokemon["primary_type"]=="grass"]
display(grass_df_pokemon)
# Out:
#      national_number   gen english_name japanese_name primary_type  \
# 0                  1     I    Bulbasaur   Fushigidane        grass
# 1                  2     I      Ivysaur    Fushigisou        grass
# 2                  3     I     Venusaur   Fushigibana        grass
# 42                43     I       Oddish    Nazonokusa        grass
# 43                44     I        Gloom     Kusaihana        grass
# ..               ...   ...          ...           ...          ...
# 828              829  VIII   Gossifleur       Himenka        grass
# 829              830  VIII     Eldegoss   Watashiraga        grass
# 839              840  VIII       Applin      Kajitchu        grass
# 840              841  VIII      Flapple        Appryu        grass
# 841              842  VIII     Appletun      Tarupple        grass
#
#     secondary_type        classification percent_male percent_female  \
# 0           poison          Seed Pokémon        88.14          11.86
# ...

# %%
grass_water_df_pokemon = df_pokemon[(df_pokemon["primary_type"] == "grass") & (df_pokemon["secondary_type"] == "water")]
display(grass_water_df_pokemon)
# Out:
# Empty DataFrame
# Columns: [national_number, gen, english_name, japanese_name, primary_type, secondary_type, classification, percent_male, percent_female, height_m, weight_kg, capture_rate, base_egg_steps, hp, attack, defense, sp_attack, sp_defense, speed, abilities_0, abilities_1, abilities_2, abilities_hidden, against_normal, against_fire, against_water, against_electric, against_grass, against_ice, against_fighting, against_poison, against_ground, against_flying, against_psychic, against_bug, against_rock, against_ghost, against_dragon, against_dark, against_steel, against_fairy, is_sublegendary, is_legendary, is_mythical, evochain_0, evochain_1, evochain_2, evochain_3, evochain_4, evochain_5, evochain_6, gigantamax, mega_evolution, mega_evolution_alt, description]
# Index: []
#
# [0 rows x 55 columns]

# %% [markdown]
# ## Pegando os pokémons do tipo Grama =🌱 e Venenoso = ☣️

# %%
grass_poison_df_pokemon = df_pokemon[(df_pokemon["primary_type"]=="grass") & (df_pokemon["secondary_type"]=="poison")]
display(grass_poison_df_pokemon)
# Out:
#      national_number  gen english_name japanese_name primary_type  \
# 0                  1    I    Bulbasaur   Fushigidane        grass
# 1                  2    I      Ivysaur    Fushigisou        grass
# 2                  3    I     Venusaur   Fushigibana        grass
# 42                43    I       Oddish    Nazonokusa        grass
# 43                44    I        Gloom     Kusaihana        grass
# 44                45    I    Vileplume     Ruffresia        grass
# 68                69    I   Bellsprout   Madatsubomi        grass
# 69                70    I   Weepinbell       Utsudon        grass
# 70                71    I   Victreebel       Utsubot        grass
# 314              315  III      Roselia       Roselia        grass
# 405              406   IV        Budew       Subomie        grass
# 406              407   IV     Roserade      Roserade        grass
# 589              590    V      Foongus    Tamagetake        grass
# ...

# %% [markdown]
# ## Pegando os pokémons do tipo Grama =🌱 e Dragão = 🐉

# %%
grass_drgon_df_pokemon = df_pokemon[(df_pokemon["primary_type"] == "grass") & (df_pokemon["secondary_type"] == "dragon")]
display(grass_drgon_df_pokemon)
# Out:
#      national_number   gen english_name japanese_name primary_type  \
# 839              840  VIII       Applin      Kajitchu        grass
# 840              841  VIII      Flapple        Appryu        grass
# 841              842  VIII     Appletun      Tarupple        grass
#
#     secondary_type        classification percent_male percent_female  \
# 839         dragon    Apple Core Pokémon         50.2           49.8
# 840         dragon    Apple Wing Pokémon         50.2           49.8
# 841         dragon  Apple Nectar Pokémon         50.2           49.8
#
#      height_m  ...      evochain_1 evochain_2       evochain_3  evochain_4  \
# 839       0.2  ...  Use Tart Apple    Flapple  Use Sweet Apple    Appletun
# 840       0.3  ...  Use Tart Apple    Flapple  Use Sweet Apple    Appletun
# 841       0.4  ...  Use Tart Apple    Flapple  Use Sweet Apple    Appletun
#
#      evochain_5  evochain_6          gigantamax  mega_evolution  \
# ...

# %% [markdown]
# ## Área de Estudo: Fogo
# ## Pegandos todos os pokémons do primeiro tipo fire 🔥

# %%
fire_df_pokemon = df_pokemon[df_pokemon["primary_type"]=="fire"]
display(fire_df_pokemon)
# Out:
#      national_number   gen english_name japanese_name primary_type  \
# 3                  4     I   Charmander      Hitokage         fire
# 4                  5     I   Charmeleon       Lizardo         fire
# 5                  6     I    Charizard      Lizardon         fire
# 36                37     I       Vulpix         Rokon         fire
# 37                38     I    Ninetales        Kyukon         fire
# 57                58     I    Growlithe        Gardie         fire
# 58                59     I     Arcanine        Windie         fire
# 76                77     I       Ponyta        Ponyta         fire
# 77                78     I     Rapidash        Gallop         fire
# 125              126     I       Magmar        Boober         fire
# 135              136     I      Flareon       Booster         fire
# 145              146     I      Moltres          Fire         fire
# 154              155    II    Cyndaquil    Hinoarashi         fire
# ...

# %% [markdown]
# ## Pegando os pokémons do tipo Fire = 🔥 e Grama = 🌱

# %%
fire_grass_df_pokemon = df_pokemon[(df_pokemon["primary_type"]=="fire") & (df_pokemon["primary_type"]=="grass")]
display(fire_grass_df_pokemon)
print(f"Podemos analisar que não existe ainda pokémnos de tipo fogo e grama ao mesmo tempo")
# Out:
# Empty DataFrame
# Columns: [national_number, gen, english_name, japanese_name, primary_type, secondary_type, classification, percent_male, percent_female, height_m, weight_kg, capture_rate, base_egg_steps, hp, attack, defense, sp_attack, sp_defense, speed, abilities_0, abilities_1, abilities_2, abilities_hidden, against_normal, against_fire, against_water, against_electric, against_grass, against_ice, against_fighting, against_poison, against_ground, against_flying, against_psychic, against_bug, against_rock, against_ghost, against_dragon, against_dark, against_steel, against_fairy, is_sublegendary, is_legendary, is_mythical, evochain_0, evochain_1, evochain_2, evochain_3, evochain_4, evochain_5, evochain_6, gigantamax, mega_evolution, mega_evolution_alt, description]
# Index: []
#
# [0 rows x 55 columns]
# Podemos analisar que não existe ainda pokémnos de tipo fogo e grama ao mesmo tempo

# %% [markdown]
# ## Pegando os pokémons do tipo Fire = 🔥 e Água = 💧

# %%
fire_water_df_pokemon = df_pokemon[(df_pokemon["primary_type"]=="fire") & (df_pokemon["secondary_type"]=="water")]
display(fire_water_df_pokemon)
# Out:
#      national_number gen english_name japanese_name primary_type  \
# 720              721  VI    Volcanion     Volcanion         fire
#
#     secondary_type classification percent_male percent_female  height_m  ...  \
# 720          water  Steam Pokémon          NaN            NaN       1.7  ...
#
#      evochain_1 evochain_2  evochain_3  evochain_4  evochain_5  evochain_6  \
# 720         NaN        NaN         NaN         NaN         NaN         NaN
#
#      gigantamax  mega_evolution  mega_evolution_alt  \
# 720         NaN             NaN                 NaN
#
#                                            description
# 720  It lets out billows of steam and disappears in...
#
# [1 rows x 55 columns]

# %% [markdown]
# ## Pegando os pokémons do tipo Fire = 🔥 e Venenoso =

# %%
fire__poison_df_pokemon = df_pokemon[(df_pokemon["primary_type"]=="fire") & (df_pokemon["secondary_type"]=="poison")]
display(fire__poison_df_pokemon)
print(f"Podemos analisar que não exist nenhum pokémon com o primeiro tipo fogo com um segundo tipo venenoso")
# Out:
# Empty DataFrame
# Columns: [national_number, gen, english_name, japanese_name, primary_type, secondary_type, classification, percent_male, percent_female, height_m, weight_kg, capture_rate, base_egg_steps, hp, attack, defense, sp_attack, sp_defense, speed, abilities_0, abilities_1, abilities_2, abilities_hidden, against_normal, against_fire, against_water, against_electric, against_grass, against_ice, against_fighting, against_poison, against_ground, against_flying, against_psychic, against_bug, against_rock, against_ghost, against_dragon, against_dark, against_steel, against_fairy, is_sublegendary, is_legendary, is_mythical, evochain_0, evochain_1, evochain_2, evochain_3, evochain_4, evochain_5, evochain_6, gigantamax, mega_evolution, mega_evolution_alt, description]
# Index: []
#
# [0 rows x 55 columns]
# Podemos analisar que não exist nenhum pokémon com o primeiro tipo fogo com um segundo tipo venenoso

# %% [markdown]
# ## Pegando os pokémons do tipo Fire = 🔥 e Elétrico =

# %%
fire_eletric_df_pokemon = df_pokemon[(df_pokemon["primary_type"]=="fire") & (df_pokemon["secondary_type"]=="eletric")]
display(fire_eletric_df_pokemon)
print(f"Pegando os pokémons do tipo Fire = 🔥 e Elétrico = Podemos analisar que não existe nenhum pokémon com o primeiro tipo fogo com um segundo tipo elétrico")
# Out:
# Empty DataFrame
# Columns: [national_number, gen, english_name, japanese_name, primary_type, secondary_type, classification, percent_male, percent_female, height_m, weight_kg, capture_rate, base_egg_steps, hp, attack, defense, sp_attack, sp_defense, speed, abilities_0, abilities_1, abilities_2, abilities_hidden, against_normal, against_fire, against_water, against_electric, against_grass, against_ice, against_fighting, against_poison, against_ground, against_flying, against_psychic, against_bug, against_rock, against_ghost, against_dragon, against_dark, against_steel, against_fairy, is_sublegendary, is_legendary, is_mythical, evochain_0, evochain_1, evochain_2, evochain_3, evochain_4, evochain_5, evochain_6, gigantamax, mega_evolution, mega_evolution_alt, description]
# Index: []
#
# [0 rows x 55 columns]
# Pegando os pokémons do tipo Fire = 🔥 e Elétrico = Podemos analisar que não existe nenhum pokémon com o primeiro tipo fogo com um segundo tipo elétrico

# %% [markdown]
# ## Pegando os pokémons do tipo Fire = 🔥 e Dragão = 🐉

# %%
fire_dragon_df_pokemon = df_pokemon[(df_pokemon["primary_type"]=="fire") & (df_pokemon["secondary_type"]=="dragon")]
display(fire_dragon_df_pokemon)
# Out:
#      national_number  gen english_name japanese_name primary_type  \
# 775              776  VII   Turtonator     Bakugames         fire
#
#     secondary_type        classification percent_male percent_female  \
# 775         dragon  Blast Turtle Pokémon         50.2           49.8
#
#      height_m  ...  evochain_1 evochain_2  evochain_3  evochain_4  evochain_5  \
# 775       2.0  ...         NaN        NaN         NaN         NaN         NaN
#
#      evochain_6  gigantamax  mega_evolution  mega_evolution_alt  \
# 775         NaN         NaN             NaN                 NaN
#
#                                            description
# 775  Explosive substances coat the shell on its bac...
#
# [1 rows x 55 columns]

# %% [markdown]
# ## Pegando os pokémons por Geração e Tipo Venenoso

# %%
gen_poison_df_pokemon = df_pokemon[(df_pokemon["gen"] == "I") & (df_pokemon["primary_type"] == "poison")]
display(gen_poison_df_pokemon)
linhas, colunas= gen_poison_df_pokemon.shape
print(f"Geração I existem um total de {linhas} pokémons venososos")
# Out:
#      national_number gen english_name japanese_name primary_type  \
# 22                23   I        Ekans          Arbo       poison
# 23                24   I        Arbok         Arbok       poison
# 28                29   I     Nidoran♀      Nidoran♀       poison
# 29                30   I     Nidorina      Nidorina       poison
# 30                31   I    Nidoqueen     Nidoqueen       poison
# 31                32   I     Nidoran♂      Nidoran♂       poison
# 32                33   I     Nidorino      Nidorino       poison
# 33                34   I     Nidoking      Nidoking       poison
# 40                41   I        Zubat         Zubat       poison
# 41                42   I       Golbat        Golbat       poison
# 87                88   I       Grimer      Betbeter       poison
# 88                89   I          Muk      Betbeton       poison
# 108              109   I      Koffing        Dogars       poison
# ...

# %% [markdown]
# ##

# %%
grass_df_pokemon = df_pokemon[(df_pokemon["gen"] == "I") & (df_pokemon["primary_type"] == "grass") & (df_pokemon["secondary_type"] == "poison")]
display(grass_df_pokemon)
# Out:
#     national_number gen english_name japanese_name primary_type  \
# 0                 1   I    Bulbasaur   Fushigidane        grass
# 1                 2   I      Ivysaur    Fushigisou        grass
# 2                 3   I     Venusaur   Fushigibana        grass
# 42               43   I       Oddish    Nazonokusa        grass
# 43               44   I        Gloom     Kusaihana        grass
# 44               45   I    Vileplume     Ruffresia        grass
# 68               69   I   Bellsprout   Madatsubomi        grass
# 69               70   I   Weepinbell       Utsudon        grass
# 70               71   I   Victreebel       Utsubot        grass
#
#    secondary_type      classification percent_male percent_female  height_m  \
# 0          poison        Seed Pokémon        88.14          11.86       0.7
# 1          poison        Seed Pokémon        88.14          11.86       1.0
# 2          poison        Seed Pokémon        88.14          11.86       2.0
# ...

# %%
weakness_df_pokemon = df_pokemon[['english_name','primary_type','against_water']]
weakness_df_pokemon
# Out:
#     english_name primary_type  against_water
# 0      Bulbasaur        grass            0.5
# 1        Ivysaur        grass            0.5
# 2       Venusaur        grass            0.5
# 3     Charmander         fire            2.0
# 4     Charmeleon         fire            2.0
# ..           ...          ...            ...
# 893    Regieleki     electric            1.0
# 894    Regidrago       dragon            0.5
# 895    Glastrier          ice            1.0
# 896    Spectrier        ghost            1.0
# 897      Calyrex      psychic            0.5
#
# [898 rows x 3 columns]

# %%
weakness_df_pokemon = df_pokemon[df_pokemon['against_water' ] > 1]
weakness_df_pokemon[["english_name","primary_type","against_water"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 weakness_df_pokemon = df_pokemon[df_pokemon['against_water' ] > 1]
#       2 weakness_df_pokemon[["english_name","primary_type","against_water"]]
#
# NameError: name 'df_pokemon' is not defined

# %%
weakness_df_pokemon = df_pokemon[(df_pokemon['against_water' ] > 2) & (df_pokemon['against_ground' ] > 2)]
weakness_df_pokemon[["english_name","primary_type","against_water","against_ground"]]
# Out:
#     english_name primary_type  against_water  against_ground
# 218     Magcargo         fire            4.0             4.0
# 837       Carkol         rock            4.0             4.0
# 838    Coalossal         rock            4.0             4.0

# %%
weakness_df_pokemon = df_pokemon[(df_pokemon['against_water' ] > 2) & (df_pokemon['against_ground' ] > 2)]
weakness_df_pokemon[["english_name","primary_type","secondary_type","against_water","against_ground"]]
# Out:
#     english_name primary_type secondary_type  against_water  against_ground
# 218     Magcargo         fire           rock            4.0             4.0
# 837       Carkol         rock           fire            4.0             4.0
# 838    Coalossal         rock           fire            4.0             4.0

# %%
mega_evolution_df_pokemon = df_pokemon[['english_name','mega_evolution']]
mega_evolution_df_pokemon
# Out:
#     english_name mega_evolution
# 0      Bulbasaur            NaN
# 1        Ivysaur            NaN
# 2       Venusaur  Mega Venusaur
# 3     Charmander            NaN
# 4     Charmeleon            NaN
# ..           ...            ...
# 893    Regieleki            NaN
# 894    Regidrago            NaN
# 895    Glastrier            NaN
# 896    Spectrier            NaN
# 897      Calyrex            NaN
#
# [898 rows x 2 columns]

# %%
mega_evolution_df_pokemon = df_pokemon[df_pokemon['mega_evolution'].notna()]
mega_evolution_df_pokemon
# Out:
#      national_number  gen english_name japanese_name primary_type  \
# 2                  3    I     Venusaur   Fushigibana        grass
# 5                  6    I    Charizard      Lizardon         fire
# 8                  9    I    Blastoise         Kamex        water
# 14                15    I     Beedrill         Spear          bug
# 17                18    I      Pidgeot        Pigeot       normal
# 64                65    I     Alakazam        Foodin      psychic
# 79                80    I      Slowbro       Yadoran        water
# 93                94    I       Gengar        Gangar        ghost
# 114              115    I   Kangaskhan        Garura       normal
# 126              127    I       Pinsir       Kailios          bug
# 129              130    I     Gyarados      Gyarados        water
# 141              142    I   Aerodactyl         Ptera         rock
# 149              150    I       Mewtwo        Mewtwo      psychic
# ...
